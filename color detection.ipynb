# %%
import geocoder
import urllib
import requests
import googlemaps
import math
import operator

from cStringIO import StringIO
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt

import wx
import os

# %%
url = "https://maps.googleapis.com/maps/api/staticmap?center=UniversityofWashington,WA&zoom=18&size=640x640&scale=1&maptype=satellite&key=AIzaSyCCtyqkReqhjOkVdyVC2kmapF9iveVMFH8"

response = StringIO(urllib.urlopen(url).read())
image = Image.open(response)

# open by image viewer
# image.show()

# save and view inline
image.save('image.bmp')
plt.imshow(image)
plt.show()

# %%
img = Image.open("image.bmp")
colors = img.getcolors(256)
max_occurence, most_present = 0, 0
try:
    for c in colors:
#         print c
        if c[0] > max_occurence:
            (max_occurence, most_present) = c
except TypeError:
    raise Exception("Too many colors in the image")

print max_occurence, most_present
# Out:
# 9841 22

# %%
test = sorted(colors, key=operator.itemgetter(0), reverse=True)
cc = test[:10]
print cc
# Out:
# [(9841, 22), (4293, 217), (4135, 150), (4097, 20), (3946, 11), (3881, 132), (3855, 34), (3783, 178), (3594, 24), (3587, 56)]

# %%
from xtermcolor import colorize

for i in cc:
    print colorize("color "+str(i[1]), ansi = i[1])
# Out:
# color 22
# color 217
# color 150
# color 20
# color 11
# color 132
# color 34
# color 178
# color 24
# color 56

# %% [markdown]
# reference
# https://stackoverflow.com/questions/7490491/capture-embedded-google-map-image-with-python-without-using-a-browser
#
# caculater 1 pixel = meter
# https://groups.google.com/forum/#!topic/google-maps-js-api-v3/hDRO4oHVSeM
#
# for Xterm Color Value
# https://jonasjacek.github.io/colors/
#
# Remaining questions -
# 1. grey are seperated to pink + yellow
# 2. find center coordinates in each image
# 3. combine multiple images to one
